# %%
def factorial(n):
    '''
    This function calculates the factorial of a given number n.
    '''
    if n <= 1:
        return 1
    else:
        return n *  factorial(n - 1)

def Statistics(arr):
    '''
    This function calculates the Minmum, Maximum, Sum, and Average deviation of a given array.
    '''
    if a == 1:
        length = len(arr)
        Minmum = min(arr)
        Maximum = max(arr)
        Sum = sum(arr)
        Avg = Sum / length

    elif a == 2:
        length = len(arr) * len(arr[0])
        Minmum = min(min(row) for row in arr)
        Maximum = max(max(row) for row in arr)
        Sum = sum(sum(row) for row in arr)
        Avg = Sum / length

    return Minmum, Maximum, Sum, Avg

# Main program

print("Welcome to the Data Analyzer and Transformer Program\n")

choice = 1

while choice < 7:

    print("\nMain Menu:")
    print("1. Input Data")
    print("2. Display Data Summary (Built-in Functions)")
    print("3. Calculate Factorial (Recursion)")
    print("4. Filter Data by Threshold (Lambda Function)")
    print("5. Sort Data")
    print("6. Display Dataset Statistics (Return Multiple Values)")
    print("7. Exit Program")

    choice = int(input("Please enter your choice : "))
    print()

    match choice:
        case 1:
            # Input Data
            print("1. 1D Array")
            print("2. 2D Array")
            a = int(input("Enter your choice:"))
            print()
            if a == 1:
                array_1d = input("Enter data for a 1D array (separated by spaces) : ").split(" ")
                array_1d = [int(i) for i in array_1d]
                print()
                print("Data of 1D Array:")
                for i in array_1d:
                    print(i , end = " ")
                print()
            elif a == 2:
                r = int(input("Enter no. row : "))
                c = int(input("Enter no. colom : "))
                array_2d = []
                for i in range(r):
                    row = []
                    for j in range(c):
                        row.append(int(input(f"row[{i}][{j}] = ")))
                    array_2d.append(row)

                print()
                print("Data of 2D Array:")
                for i in range(r):
                    for j in range(c):
                        print(array_2d[i][j] , end = " ")
                    print()
            else:
                print("Invalid choice")
            print("\nData has been stored successfully!")

        case 2:
            # Display Data Summary (Built-in Functions)
            print("Data Summary:")

            if a == 1:
                print("- Total elements : ", len(array_1d))
                print("- Minimum value : ", min(array_1d))
                print("- Maximum value : ", max(array_1d))
                print("- Sum of all values : ", sum(array_1d))
                print("- Average values : ", sum(array_1d)/len(array_1d))

            if a == 2:
                print("- Total elements : ", (len(array_2d) * len(array_2d[0])))
                print("- Minimum value : ", min(min(row) for row in array_2d))
                print("- Maximum value : ", max(max(row) for row in array_2d))
                print("- Sum of all values : ", sum(sum(row) for row in array_2d))
                print("- Average values : ", sum(sum(row) for row in array_2d) / (len(array_2d) * len(array_2d[0])))

        case 3:
            # Calculate Factorial (Recursion)
            fact = int(input("Enter a number to calculate its factorial : "))
            print(factorial.__doc__)
            print(f"Factorial of {fact} is : ",factorial(fact))

        case 4:
            # Filter Data by Threshold (Lambda Function)
            num = int(input("Enter a threshold value to filter out data above this value : "))
            print(f"Filtered Data (values >= {num}): ")
            if a == 1:
                for i in array_1d:
                    Filter = lambda i : i if(i >= num) else 0
                    print(Filter(i) , end = " ")
            elif a == 2:
                for i in array_2d:
                    for j in i:
                        Filter = lambda j : j if(j >= num) else 0
                        print(Filter(j) , end = " ")
                    print()
            print()

        case 5:
            # Sort Data
            print("Choose sorting option : ")
            print("1. Ascending")
            print("2. Descending")
            choose = int(input("Enter your choice : "))
            print()

            if choose == 1:
                if a == 1:
                    array_1d.sort()
                    print("Sorted Data in Ascending order : ", array_1d)
                elif a == 2:
                    print("Sorted Data in Ascending order : ", sorted(array_2d))
            elif choose == 2:
                if a == 1:
                    array_1d.reverse()
                    print("Sorted Data in Descending order : ", array_1d)
                elif a == 2:
                    print("Sorted Data in Descending order : ", sorted(array_2d, reverse=True))
            else:
                print("Invalid choice")

        case 6:
            # Display Dataset Statistics (Return Multiple Values)
            print(Statistics.__doc__)
            if a == 1:
                Minmum , Maximum , Sum , Avg = Statistics(array_1d)
                print("- Minimum value : ", Minmum)
                print("- Maximum value : ", Maximum)
                print("- Sum of all values : ", Sum)
                print("- Average values : ", Avg)

            elif a == 2:
                Minmum , Maximum , Sum , Avg = Statistics(array_2d)
                print("- Minimum value : ", Minmum)
                print("- Maximum value : ", Maximum)
                print("- Sum of all values : ", Sum)
                print("- Average values : ", Avg)

        case 7:
            print("Thank you for using the Data Analyzer and Transformer Program. Goodbye!")
# Out:
# Welcome to the Data Analyzer and Transformer Program
#
#
# Main Menu:
# 1. Input Data
# 2. Display Data Summary (Built-in Functions)
# 3. Calculate Factorial (Recursion)
# 4. Filter Data by Threshold (Lambda Function)
# 5. Sort Data
# 6. Display Dataset Statistics (Return Multiple Values)
# 7. Exit Program
# Please enter your choice : 1
#
# 1. 1D Array
# 2. 2D Array
# Enter your choice:1
#
# Enter data for a 1D array (separated by spaces) : 34 12 56 78 43 21 90
#
# Data of 1D Array:
# 34 12 56 78 43 21 90
#
# Data has been stored successfully!
#
# Main Menu:
# 1. Input Data
# 2. Display Data Summary (Built-in Functions)
# 3. Calculate Factorial (Recursion)
# 4. Filter Data by Threshold (Lambda Function)
# 5. Sort Data
# 6. Display Dataset Statistics (Return Multiple Values)
# 7. Exit Program
# Please enter your choice : 2
#
# Data Summary:
# - Total elements :  7
# - Minimum value :  12
# - Maximum value :  90
# - Sum of all values :  334
# - Average values :  47.714285714285715
#
# ...
